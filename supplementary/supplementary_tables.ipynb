# %% [markdown]
# # pathway perturbation

# %%
#drug perturbation results
import scanpy as sc
import numpy as np
import pickle
from perturbation_general import perturbation
adata = sc.read_h5ad('/mnt/md0/yumin/UNAGI_old/data/mes/4/org_test/dataset.h5ad')
uns = pickle.load(open('/mnt/md0/yumin/UNAGI_old/data/mes/4/org_test/attribute.pkl', 'rb'))
keys = list(uns['random_background_perturbation_deltaD']['0.5'].keys()).copy()
del uns['random_background_perturbation_deltaD']['0.5']
del uns['random_background_perturbation_deltaD']['2.0']
del uns['pathway_perturbation_score']
# for each in keys:
#     if each[0] != '4':
        # del uns['random_background_perturbation_deltaD']['0.5'][each]
        # del uns['random_background_perturbation_deltaD']['2.0'][each]
        # del uns['pathway_perturbation_deltaD']['0.5'][each]
        # del uns['pathway_perturbation_deltaD']['2.0'][each]
        # del uns['drug_perturbation_deltaD']['0.5'][each]
        # del uns['drug_perturbation_deltaD']['2.0'][each]
adata.uns = uns
#pathway median gene len: 4
#pathway mean gene len: 8
a = perturbation(adata, '/mnt/md0/yumin/UNAGI_old/data/mes/model_save/mes_4.pth','/mnt/md0/yumin/UNAGI_old/data/mes/4/org_test/idrem')

# # # # a.run('pathway',0.5,inplace=True)
a.run('random_background',0.5,random_genes=20,random_times=1000,inplace=True)
# a.run('pathway',0.5,inplace=True)
a.analysis('pathway',0.5)
# Out:
# /home/yumin/anaconda3/envs/wks/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /mnt/md0/yumin/UNAGI_old/src/perturbation_general.py:39: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['leiden'] = adata.obs['leiden'].astype('string')
# /home/yumin/anaconda3/envs/wks/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /mnt/md0/yumin/UNAGI_old/src/perturbation_general.py:39: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['leiden'] = adata.obs['leiden'].astype('string')
# ...

# %%
total_len = [len(adata.uns['data_drug_overlap_genes'][each]) for each in list(adata.uns['data_drug_overlap_genes'].keys())]

# %%
import pandas as pd
pd.DataFrame.from_dict(adata.uns['pathway_perturbation_score']['0.5']['total']['top_compounds']).to_csv('4_pathway_high_precesion_1125_20.csv')

# %% [markdown]
# # Drug perturbation

# %%
np.median(total_len)
