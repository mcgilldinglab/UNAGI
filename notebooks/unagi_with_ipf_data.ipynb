# %%
import os
import shutil
from UNAGI import UNAGI
import warnings


warnings.filterwarnings('ignore')
unagi = UNAGI()

# %%
os.listdir('/datasets/dcfm_project/ipf_data_bak/')
# Out:
# ['0', '1.h5ad', '0.h5ad', 'model_save', '2.h5ad', '3.h5ad']

# %%
unagi.setup_data(
    '/datasets/dcfm_project/ipf_data_bak/',
    total_stage=4,
    stage_key='stage')
# Out:
# Cell graphs found, skipping cell graph construction!

# %%
unagi.setup_training(
    task="IPF_main",
    dist="ziln",          # paper’s choice for IPF
    device="cuda:1",      # use your GPU; change if needed
    epoch_iter=10,        # default used by the package unless overridden
    epoch_initial=20,     # default used by the package unless overridden
    lr=1e-4,              # package default
    lr_dis=5e-4,          # package default (discriminator)
    beta=1.0,             # package default
    hidden_dim=256,       # package default
    latent_dim=64,        # package default
    graph_dim=1024,       # package default
    BATCHSIZE=512,        # package default
    max_iter=10,          # outer iterations
    GPU=True,             # run on CUDA
    adversarial=True,     # paper uses GAN
    GCN=True              # paper uses GCN
)

# %%
unagi.run_UNAGI(idrem_dir = '../idrem')
# Out:
# Species: Running on Human data
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 unagi.run_UNAGI(idrem_dir = '../idrem')
#
# File /workspace/UNAGI/UNAGI/UNAGI_tool.py:464, in UNAGI.run_UNAGI(self, idrem_dir, CPO, resume, resume_iteration, connect_edges_cutoff)
#     459     else:
#     460         unagi_runner.set_up_iDREM(
#     461             Minimum_Absolute_Log_Ratio_Expression=self.iDREM_parameters['Minimum_Absolute_Log_Ratio_Expression'],
#     462             Convergence_Likelihood=self.iDREM_parameters['Convergence_Likelihood'],
#     463             Minimum_Standard_Deviation=self.iDREM_parameters['Minimum_Standard_Deviation'])
# --> 464 unagi_runner.run(CPO)
#
# File /workspace/UNAGI/UNAGI/train/runner.py:272, in UNAGI_runner.run(self, CPO)
#     270 else:
#     271     is_iterative = True
# --> 272 self.trainer.train(self.all_in_one,self.iteration,target_dir=self.data_path,adversarial=self.adversarial,is_iterative=is_iterative)
#     273 if CPO:
#     274     self.run_CPO()
#
# File /workspace/UNAGI/UNAGI/train/trainer.py:296, in UNAGI_trainer.train(self, adata, iteration, target_dir, adversarial, is_iterative)
#     293     vae = self.model
#     294     dis = self.dis_model
# --> 296 vae.to(self.device)
#     297 if adversarial:
#     298     dis.to(self.device)
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/nn/modules/module.py:1369, in Module.to(self, *args, **kwargs)
#    1366         else:
#    1367             raise
# -> 1369 return self._apply(convert)
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/nn/modules/module.py:955, in Module._apply(self, fn, recurse)
#     951 # Tensors stored in modules are graph leaves, and we don't want to
#     952 # track autograd history of `param_applied`, so we have to use
#     953 # `with torch.no_grad():`
#     954 with torch.no_grad():
# --> 955     param_applied = fn(param)
#     956 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     958 from torch._subclasses.fake_tensor import FakeTensor
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/nn/modules/module.py:1355, in Module.to.<locals>.convert(t)
#    1348     if convert_to_format is not None and t.dim() in (4, 5):
#    1349         return t.to(
#    1350             device,
#    1351             dtype if t.is_floating_point() or t.is_complex() else None,
#    1352             non_blocking,
#    1353             memory_format=convert_to_format,
#    1354         )
# -> 1355     return t.to(
#    1356         device,
#    1357         dtype if t.is_floating_point() or t.is_complex() else None,
#    1358         non_blocking,
#    1359     )
#    1360 except NotImplementedError as e:
#    1361     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File /opt/conda/envs/unagi/lib/python3.11/site-packages/torch/cuda/__init__.py:412, in _lazy_init()
#     410 if "CUDA_MODULE_LOADING" not in os.environ:
#     411     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 412 torch._C._cuda_init()
#     413 # Some of the queued calls may reentrantly call _lazy_init();
#     414 # we need to just return without initializing in that case.
#     415 # However, we must not let any *other* threads in!
#     416 _tls.is_initializing = True
#
# RuntimeError: No CUDA GPUs are available
