# %%
import pickle
import scanpy as sc
from UNAGI import plotting
# !gzip -d example_1/attribute.pkl.gz
adata = sc.read_h5ad('example_1/dataset.h5ad')
adata.uns = pickle.load(open('example_1/attribute.pkl', 'rb'))

# %% [markdown]
# # Visualize the cell type composition acorss stages

# %%
plotting.plot_cell_type_composition(adata,'ident','stage',dpi=100)

# %% [markdown]
# # Visualize the cell embeddings colouring by cell types

# %%
plotting.plot_stages_latent_representation(adata,'ident','stage',dpi=100)
# Out:
# 6750
# ARI:  0.3528979783012028
# NMIs:  0.4038211594090081
# silhouette score:  0.051326415901465444
# 3152
# ARI:  0.37581902301361386
# NMIs:  0.4705933429614055
# silhouette score:  0.067180553146954
# 4195
# ARI:  0.4788949237386232
# NMIs:  0.4811410978226817
# silhouette score:  0.048027576034055344
# 13550
# ARI:  0.4297843699783552
# NMIs:  0.5672054715862501
# silhouette score:  0.1050074911451904
# ARIs:  [0.40934907375794877]
# NMI:  [0.4806902679448364]
# silhouette score:  0.06788550905691629

# %% [markdown]
# # Plot the dendrogram of each stage data

# %%
plotting.plot_hc_dendrogram(adata,'stage','ident')

# %% [markdown]
# ## Visualize thier hierarchical markers using heatmaps

# %%
plotting.hierarchical_static_markers_heatmap(adata,0,3,1,20,'stage','ident')
# Out:
# WARNING: `var_names` is a dictionary. This will reset the current value of `var_group_labels` and `var_group_positions`.

# %% [markdown]
# ## Visualize the pathway perturabtion results

# %%
import pandas as pd

pd.DataFrame.from_dict(adata.uns['drug_perturbation_score']['0.5']['total']['top_compounds'])
# Out:
#                                              compound  perturbation score  \
# 0                                   ODQ,YC-1,LY-83583            0.672385
# 1   BRL-54443,LY-344864,rizatriptan,sumatriptan,zo...            0.357917
# 2                                           ibudilast            0.322838
# 3   pimobendan,amrinone,anagrelide,cilostamide,cil...            0.314900
# 4                                        8-bromo-cGMP            0.249793
# 5                                                W-13            0.210600
# 6                                            KI-16425            0.207807
# 7           calmidazolium,vinpocetine,propentofylline            0.178862
# 8                                            doxapram            0.177309
# 9                                       BRD-K19059335            0.176811
# 10                                          minoxidil            0.169520
# 11                                       dipyridamole            0.142387
# 12                                          pinacidil            0.142373
# 13                                         zonisamide            0.136571
# 14  valproic-acid,lacosamide,oxcarbazepine,carbama...            0.135161
# 15                                            ABT-702            0.092845
# 16  CTEP,MPEP,dihydroxyphenylglycine,DMeOB,basimgl...            0.092231
# 17                                        regorafenib            0.090860
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                                NaN                 NaN
# 30                                                NaN                 NaN
# 31                                                NaN                 NaN
# 32                                                NaN                 NaN
# 33                                                NaN                 NaN
# 34                                                NaN                 NaN
# 35                                                NaN                 NaN
# 36                                                NaN                 NaN
# 37                                                NaN                 NaN
# 38                                                NaN                 NaN
# 39                                                NaN                 NaN
# 40                                                NaN                 NaN
# 41                                                NaN                 NaN
# 42                                                NaN                 NaN
# 43                                                NaN                 NaN
# 44                                                NaN                 NaN
# 45                                                NaN                 NaN
# 46                                                NaN                 NaN
# 47                                                NaN                 NaN
# 48                                                NaN                 NaN
# 49                                                NaN                 NaN
# 50                                                NaN                 NaN
# 51                                                NaN                 NaN
# 52                                                NaN                 NaN
# 53                                                NaN                 NaN
# 54                                                NaN                 NaN
#
#     pval_adjusted                                drug_regulation  \
# 0    0.000000e+00                                    [GUCY1A2:-]
# 1    0.000000e+00                                      [HTR1F:+]
# 2    1.998401e-15                   [PDE10A:-, PDE3A:-, PDE4D:+]
# 3    1.318945e-14                                      [PDE3A:+]
# 4    6.640099e-09                                      [PRKG1:+]
# 5    3.321988e-06                              [MYLK:-, PDE1A:+]
# 6    5.308397e-06                             [LPAR1:-, LPAR3:-]
# 7    2.224760e-04                                      [PDE1A:+]
# 8    2.919220e-04                                      [KCNK3:-]
# 9    3.430863e-04                                      [RUNX1:-]
# 10   8.576554e-04                                      [ABCC9:+]
# 11   1.312342e-02                            [PDE10A:-, PDE7B:-]
# 12   1.532901e-02                             [ABCC9:+, ABCC8:+]
# 13   2.969028e-02            [SCN1A:+, SCN2A:-, SCN3A:-, CA12:-]
# 14   4.152355e-02                             [SCN1A:+, SCN3A:-]
# 15   7.974672e-01                                        [ADK:-]
# 16   1.000000e+00                                       [GRM5:-]
# 17   1.000000e+00  [FGFR2:+, FLT1:+, FRK:+, KDR:+, KIT:+, TEK:+]
# 18            NaN                                            NaN
# 19            NaN                                            NaN
# 20            NaN                                            NaN
# 21            NaN                                            NaN
# 22            NaN                                            NaN
# 23            NaN                                            NaN
# 24            NaN                                            NaN
# 25            NaN                                            NaN
# 26            NaN                                            NaN
# 27            NaN                                            NaN
# 28            NaN                                            NaN
# 29            NaN                                            NaN
# 30            NaN                                            NaN
# 31            NaN                                            NaN
# 32            NaN                                            NaN
# 33            NaN                                            NaN
# 34            NaN                                            NaN
# 35            NaN                                            NaN
# 36            NaN                                            NaN
# 37            NaN                                            NaN
# 38            NaN                                            NaN
# 39            NaN                                            NaN
# 40            NaN                                            NaN
# 41            NaN                                            NaN
# 42            NaN                                            NaN
# 43            NaN                                            NaN
# 44            NaN                                            NaN
# 45            NaN                                            NaN
# 46            NaN                                            NaN
# 47            NaN                                            NaN
# 48            NaN                                            NaN
# 49            NaN                                            NaN
# 50            NaN                                            NaN
# 51            NaN                                            NaN
# 52            NaN                                            NaN
# 53            NaN                                            NaN
# 54            NaN                                            NaN
#
#                                  idrem_suggestion
# 0                                     [GUCY1A2:+]
# 1                                       [HTR1F:+]
# 2                    [PDE10A:-, PDE3A:+, PDE4D:+]
# 3                                       [PDE3A:+]
# 4                                       [PRKG1:+]
# 5                               [MYLK:-, PDE1A:-]
# 6                              [LPAR1:+, LPAR3:-]
# 7                                       [PDE1A:-]
# 8                                       [KCNK3:+]
# 9                                       [RUNX1:-]
# 10                                      [ABCC9:+]
# 11                            [PDE10A:-, PDE7B:-]
# 12                             [ABCC9:+, ABCC8:+]
# 13            [SCN1A:+, SCN2A:-, SCN3A:-, CA12:-]
# 14                             [SCN1A:+, SCN3A:-]
# 15                                        [ADK:+]
# 16                                       [GRM5:-]
# 17  [FGFR2:-, FLT1:+, FRK:-, KDR:+, KIT:-, TEK:-]
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                            NaN
# 40                                            NaN
# 41                                            NaN
# 42                                            NaN
# 43                                            NaN
# 44                                            NaN
# 45                                            NaN
# 46                                            NaN
# 47                                            NaN
# 48                                            NaN
# 49                                            NaN
# 50                                            NaN
# 51                                            NaN
# 52                                            NaN
# 53                                            NaN
# 54                                            NaN
